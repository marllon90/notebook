# %% [markdown]
# # Gráfico para exemplo
#
# Teste com o notebook

# %%
import matplotlib.pyplot as plt
import pandas
import requests

api_key='01jy3PWmYLvDd9ndNhAzBaBsdAizdXM2'
city='1-45881_1_AL'

url = f'http://dataservice.accuweather.com/forecasts/v1/daily/5day/{city}?apikey={api_key}&language=pt-br&details=true&metric=true'

data = requests.get(url)

df = pandas.read_csv('../data/personagens.csv')
#df = pandas.json_normalize(data.json()['DailyForecasts'])
print(df)
x = df['personagem']
y = df['altura']

plt.bar(x,y)
plt.title("Altura dos personagens")
plt.xlabel('Personagem')
plt.ylabel('Altura')
plt.show()
# Out:
#   personagem  altura
# 0      panda     159
# 1    roberto     145
# 2          c     200
