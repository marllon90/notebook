# %% [markdown]
# # Gráfico para exemplo
#
# This notebooks reads sample population data from `data/atlantis.csv` and plots it using Matplotlib. Edit `data/atlantis.csv` and re-run this cell to see how the plots change!

# %%
import matplotlib.pyplot as plt
import pandas
import requests

api_key='01jy3PWmYLvDd9ndNhAzBaBsdAizdXM2'
city='1-45881_1_AL'

url = f'http://dataservice.accuweather.com/forecasts/v1/daily/5day/{city}?apikey={api_key}&language=pt-br&details=true&metric=true'

data = requests.get(url)
print(data.json())

df = pandas.read_csv('../data/atlantis.csv')
x = df['year']
y = df['population']

plt.plot(x,y)
plt.title("População de Atlantis")
plt.xlabel('Ano')
plt.ylabel('População')
plt.show()
# Out:
# {'Headline': {'EffectiveDate': '2023-01-18T13:00:00-03:00', 'EffectiveEpochDate': 1674057600, 'Severity': 5, 'Text': 'Uma tempestade amanhã à tarde', 'Category': 'thunderstorm', 'EndDate': '2023-01-18T19:00:00-03:00', 'EndEpochDate': 1674079200, 'MobileLink': 'http://www.accuweather.com/pt/br/sao-paulo/1-45881_1_al/daily-weather-forecast/1-45881_1_al?unit=c&lang=pt-br', 'Link': 'http://www.accuweather.com/pt/br/sao-paulo/1-45881_1_al/daily-weather-forecast/1-45881_1_al?unit=c&lang=pt-br'}, 'DailyForecasts': [{'Date': '2023-01-17T07:00:00-03:00', 'EpochDate': 1673949600, 'Sun': {'Rise': '2023-01-17T05:34:00-03:00', 'EpochRise': 1673944440, 'Set': '2023-01-17T18:58:00-03:00', 'EpochSet': 1673992680}, 'Moon': {'Rise': '2023-01-17T01:04:00-03:00', 'EpochRise': 1673928240, 'Set': '2023-01-17T14:49:00-03:00', 'EpochSet': 1673977740, 'Phase': 'WaningCrescent', 'Age': 25}, 'Temperature': {'Minimum': {'Value': 19.6, 'Unit': 'C', 'UnitType': 17}, 'Maximum': {'Value': 30.2, 'Unit': 'C', 'UnitType': 17}}, 'RealFeelTemperature': {'Minimum': {'Value': 19.9, 'Unit': 'C', 'UnitType': 17, 'Phrase': 'Agradável'}, 'Maximum': {'Value': 37.1, 'Unit': 'C', 'UnitType': 17, 'Phrase': 'Quente'}}, 'RealFeelTemperatureShade': {'Minimum': {'Value': 19.9, 'Unit': 'C', 'UnitType': 17, 'Phrase': 'Agradável'}, 'Maximum': {'Value': 30.4, 'Unit': 'C', 'UnitType': 17, 'Phrase': 'Calor'}}, 'HoursOfSun': 7.2, 'DegreeDaySummary': {'Heating': {'Value': 0.0, 'Unit': 'C', 'UnitType': 17}, 'Cooling': {'Value': 7.0, 'Unit': 'C', 'UnitType': 17}}, 'AirAndPollen': [{'Name': 'AirQuality', 'Value': 0, 'Category': 'Boa', 'CategoryValue': 1, 'Type': 'Ozônio'}, {'Name': 'Grass', 'Value': 0, 'Category': 'Boa', 'CategoryValue': 1}, {'Name': 'Mold', 'Value': 0, 'Category': 'Boa', 'CategoryValue': 1}, {'Name': 'Ragweed', 'Value': 0, 'Category': 'Boa', 'CategoryValue': 1}, {'Name': 'Tree', 'Value': 0, 'Category': 'Boa', 'CategoryValue': 1}, {'Name': 'UVIndex', 'Value': 13, 'Category': 'Mt insal', 'CategoryValue': 5}], 'Day': {'Icon': 17, 'IconPhrase': 'Parcialmente nublado, com tempestades', 'HasPrecipitation': True, 'PrecipitationType': 'Rain', 'PrecipitationIntensity': 'Moderate', 'ShortPhrase': 'Uma tempestade em partes da região', 'LongPhrase': 'Uma tempestade em partes da região', 'PrecipitationProbability': 41, 'ThunderstormProbability': 25, 'RainProbability': 41, 'SnowProbability': 0, 'IceProbability': 0, 'Wind': {'Speed': {'Value': 11.1, 'Unit': 'km/h', 'UnitType': 7}, 'Direction': {'Degrees': 133, 'Localized': 'SE', 'English': 'SE'}}, 'WindGust': {'Speed': {'Value': 31.5, 'Unit': 'km/h', 'UnitType': 7}, 'Direction': {'Degrees': 138, 'Localized': 'SE', 'English': 'SE'}}, 'TotalLiquid': {'Value': 1.7, 'Unit': 'mm', 'UnitType': 3}, 'Rain': {'Value': 1.7, 'Unit': 'mm', 'UnitType': 3}, 'Snow': {'Value': 0.0, 'Unit': 'cm', 'UnitType': 4}, 'Ice': {'Value': 0.0, 'Unit': 'mm', 'UnitType': 3}, 'HoursOfPrecipitation': 1.0, 'HoursOfRain': 1.0, 'HoursOfSnow': 0.0, 'HoursOfIce': 0.0, 'CloudCover': 49, 'Evapotranspiration': {'Value': 4.8, 'Unit': 'mm', 'UnitType': 3}, 'SolarIrradiance': {'Value': 6242.1, 'Unit': 'W/m²', 'UnitType': 33}}, 'Night': {'Icon': 38, 'IconPhrase': 'Predominantemente nublado', 'HasPrecipitation': False, 'ShortPhrase': 'Aumento de nebulosidade', 'LongPhrase': 'Aumento de nebulosidade', 'PrecipitationProbability': 16, 'ThunderstormProbability': 4, 'RainProbability': 16, 'SnowProbability': 0, 'IceProbability': 0, 'Wind': {'Speed': {'Value': 9.3, 'Unit': 'km/h', 'UnitType': 7}, 'Direction': {'Degrees': 126, 'Localized': 'SE', 'English': 'SE'}}, 'WindGust': {'Speed': {'Value': 27.8, 'Unit': 'km/h', 'UnitType': 7}, 'Direction': {'Degrees': 138, 'Localized': 'SE', 'English': 'SE'}}, 'TotalLiquid': {'Value': 0.0, 'Unit': 'mm', 'UnitType': 3}, 'Rain': {'Value': 0.0, 'Unit': 'mm', 'UnitType': 3}, 'Snow': {'Value': 0.0, 'Unit': 'cm', 'UnitType': 4}, 'Ice': {'Value': 0.0, 'Unit': 'mm', 'UnitType': 3}, 'HoursOfPrecipitation': 0.0, 'HoursOfRain': 0.0, 'HoursOfSnow': 0.0, 'Hou ...
